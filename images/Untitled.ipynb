# %%
start_x = 245
start_y = 293

adjust = 100

# %%
positions = []

for i in range(100):
    if i % 2 == 0:   
        positions.append((start_x+adjust, start_y))
        start_x -= adjust

        positions.append((start_x, start_y + adjust))
        start_y -= adjust
    else:
        positions.append((start_x+adjust, start_y))
        start_x += adjust

        positions.append((start_x, start_y + adjust))
        start_y += adjust
a = iter(positions)

# %%
next(a)
# Out:
# (-155, -107)

# %%
positions
# Out:
# [(345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
#  (245, 193),
#  (245, 293),
#  (345, 293),
#  (145, 393),
# ...
